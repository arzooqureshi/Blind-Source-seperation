# %% [markdown]
# <a href="https://colab.research.google.com/github/arzooqureshi/Blind-Source-seperation/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/arzooqureshi/Semantic-Segmentation.git
# Out:
# Cloning into 'Semantic-Segmentation'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 366 (delta 4), reused 0 (delta 0), pack-reused 354
# Receiving objects: 100% (366/366), 47.47 MiB | 21.06 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# !wget -P /content/Semantic-Segmentation/data  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_road.zip
# Out:
# --2024-02-15 10:02:16--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_road.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.75.27, 52.219.46.27, 52.219.72.195, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.75.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 470992343 (449M) [application/zip]
# Saving to: ‘/content/Semantic-Segmentation/data/data_road.zip’
#
# data_road.zip       100%[===================>] 449.17M  4.00MB/s    in 2m 26s
#
# 2024-02-15 10:04:43 (3.08 MB/s) - ‘/content/Semantic-Segmentation/data/data_road.zip’ saved [470992343/470992343]

# %%
# !unzip /content/Semantic-Segmentation/data/data_road.zip -d /content/Semantic-Segmentation/data
# Out:
# Archive:  /content/Semantic-Segmentation/data/data_road.zip
#    creating: /content/Semantic-Segmentation/data/data_road/
#    creating: /content/Semantic-Segmentation/data/data_road/training/
#    creating: /content/Semantic-Segmentation/data/data_road/testing/
#    creating: /content/Semantic-Segmentation/data/data_road/training/image_2/
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000032.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000031.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000030.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000029.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000028.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000027.png
#   inflating: /content/Semantic-Segmentation/data/data_road/training/image_2/umm_000026.png
# ...

# %%
cd /content/Semantic-Segmentation/
# Out:
# /content/Semantic-Segmentation

# %%
# !pip install backports.weakref==1.0rc1 \
             bleach==1.5.0 \
             certifi==2017.4.17 \
             chardet==3.0.4 \
             gym==0.9.1 \
             html5lib==0.9999999 \
             idna==2.5 \
             olefile==0.44 \
             pillow==4.2.1 \
             protobuf==3.4.0 \
             pyglet==1.2.4 \
             requests==2.17.3 \
             scipy==0.17.0 \
             six==1.10.0 \
             tensorflow-tensorboard==0.1.5 \
             tqdm==4.15.0 \
             urllib3==1.21.1 \
             werkzeug==0.12.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.9/375.9 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.6/156.6 kB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.3/889.3 kB 29.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.7/375.7 kB 32.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 964.6/964.6 kB 51.9 MB/s eta 0:00:00
# ...

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0

# %%
# !python /content/Semantic-Segmentation/main.py
# Out:
# 2024-02-15 10:05:55.728349: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-15 10:05:55.732743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-15 10:05:55.738820: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-15 10:05:55.774783: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import tensorflow as tf
print(dir(tf._api.v2.saved_model))
# Out:
# ['ASSETS_DIRECTORY', 'ASSETS_KEY', 'Asset', 'CLASSIFY_INPUTS', 'CLASSIFY_METHOD_NAME', 'CLASSIFY_OUTPUT_CLASSES', 'CLASSIFY_OUTPUT_SCORES', 'DEBUG_DIRECTORY', 'DEBUG_INFO_FILENAME_PB', 'DEFAULT_SERVING_SIGNATURE_DEF_KEY', 'GPU', 'LoadOptions', 'PREDICT_INPUTS', 'PREDICT_METHOD_NAME', 'PREDICT_OUTPUTS', 'REGRESS_INPUTS', 'REGRESS_METHOD_NAME', 'REGRESS_OUTPUTS', 'SAVED_MODEL_FILENAME_PB', 'SAVED_MODEL_FILENAME_PBTXT', 'SAVED_MODEL_SCHEMA_VERSION', 'SERVING', 'SaveOptions', 'TPU', 'TRAINING', 'VARIABLES_DIRECTORY', 'VARIABLES_FILENAME', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_sys', 'contains_saved_model', 'experimental', 'load', 'save']

# %%
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: 'Semantic-Segmentation' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
